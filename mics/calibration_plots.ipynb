# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from glob import glob

# %%
#!pip install opencv-python

# %%
for path in glob("calibration/*.png"):
    name = path.split("\\")[-1]
    image_1 = cv2.imread(path)

    image_1[1950:2000] = image_1[-50:]
    image_1[1850:1950] = 255
    image_1 = image_1[260:2000, 0:-50, :]
    cv2.imwrite(name, image_1)
    # plt.imshow(image_1)

# %%
# Out:
# ['calibration', 'IJBC_g1_power-0.288362T_0.2884,tau_0.33.png']

# %%
image_1[-400:].shape
# Out:
# (400, 1750, 3)

# %%
image_1[1600:2000].shape
# Out:
# (150, 1750, 3)
